# %%
import rasterio
import numpy as np
from tqdm import tqdm
from matplotlib import pyplot
from pathlib import Path

# %%
from multispectral import windows
from multispectral import corine

# %%
# !ls Data
# Out:
# Corine
# GeoWiki
# Hansen2000
# Kaggle-planet
# LT05_L1TP_168035_20061128_20180309_01_T1.tif
# LT05_L1TP_192031_20060715_20180309_01_T1.tif
# corine.tif
# corine_32629.tif
# corine_32638.tif
# corine_base.tif
# smaller.tif
# smaller_cropped.tif
# warped_small.tif

# %%
tilelist = ['Data/LT05_L1TP_168035_20061128_20180309_01_T1.tif','Data/LT05_L1TP_192031_20060715_20180309_01_T1.tif']

# %%
import imp; imp.reload(corine)
# Out:
# <module 'multispectral.corine' from 'D:\\Projects\\Satellite\\LandCover\\multispectral\\corine.py'>

# %%
corine.set_corine_directory(Path('Data'))

# %%
wds = windows.WindowedDataSet(tilelist,corine.corine_merge)

# %%
wds.next_window()
# Out:
# (<open DatasetReader name='Data/LT05_L1TP_168035_20061128_20180309_01_T1.tif' mode='r'>,
#  Window(col_off=512, row_off=0, width=256, height=256))

# %%
(x,y) = wds.next_sample()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-38-c2aa8f3e2bca> in <module>
# ----> 1 (x,y) = wds.next_sample()
#
# D:\Projects\Satellite\LandCover\multispectral\windows.py in next_sample(self)
#      56         s = None
#      57         while s is None:
# ---> 58             s = self.labeler(*self.next_window())
#      59         return s
#      60
#
# D:\Projects\Satellite\LandCover\multispectral\corine.py in corine_merge(lsdat, region)
#      32
#      33     # get the equivalent pixel boundaries for the matching corine dataset
# ---> 34     corine = fetch_corine(lsdat.crs)
#      35     geo_span = coords.pixel_to_geo(lsdat,region)
#      36     corine_region = coords.geo_to_pixel(corine,geo_span)
#
# D:\Projects\Satellite\LandCover\multispectral\corine.py in fetch_corine(crs)
#      90     corine_name = corine_directory / ("corine_" + epsg + ".tif")
# ...

# %%
x.shape
# Out:
# (6, 256, 256)

# %%
pyplot.imshow(x[1])

# %%
pyplot.imshow(y[5])
